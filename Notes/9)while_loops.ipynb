# %% [markdown]
# <a href="https://colab.research.google.com/github/sudenurozturk/Intro2Python/blob/main/while_loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # While Loops

# %%
celsius = 10

if celsius > 30:
  print('Hot 🔥')
elif 30 >= celsius > 20:
  print('Good 🟩')
elif -273 < celsius <= 20:
  print('Cold ❄️')
else:
  print('Something went wrong!')
# Out:
# Cold ❄️

# %%
celcius = 10

while celcius < 50:

  if celcius > 30:
    print('Hot 🔥')
  elif 30 >= celcius > 20:
    print('Good 🟩')
  elif -273 < celcius <= 20:
    print('Cold ❄️')
  else:
    print('Something went wrong!')
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Cold ❄️
# ...

# %%
celcius = 10

while celcius < 50:

  if celcius > 30:
    print('Hot 🔥')
  elif 30 >= celcius > 20:
    print('Good 🟩')
  elif -273 < celcius <= 20:
    print('Cold ❄️')
  else:
    print('Something went wrong!')
  celcius += 5
# Out:
# Cold ❄️
# Cold ❄️
# Cold ❄️
# Good 🟩
# Good 🟩
# Hot 🔥
# Hot 🔥
# Hot 🔥

# %%
celcius = 10

while celcius < 50:

  if celcius > 30:
    print('Hot 🔥')
  elif 30 >= celcius > 20:
    print('Good 🟩')
  elif -273 < celcius <= 20:
    print('Cold ❄️')
  else:
    print('Something went wrong!')
  print('The current temperature is',celcius)
  celcius += 5
# Out:
# Cold ❄️
# The current temperature is 10
# Cold ❄️
# The current temperature is 15
# Cold ❄️
# The current temperature is 20
# Good 🟩
# The current temperature is 25
# Good 🟩
# The current temperature is 30
# Hot 🔥
# The current temperature is 35
# Hot 🔥
# The current temperature is 40
# Hot 🔥
# The current temperature is 45

# %%
import time
celcius = 10

while celcius < 50:

  if celcius > 30:
    print('Hot 🔥')
  elif 30 >= celcius > 20:
    print('Good 🟩')
  elif -273 < celcius <= 20:
    print('Cold ❄️')
  else:
    print('Something went wrong!')
  print('The current temperature is',celcius)
  celcius += 5
  time.sleep(1.5)
# Out:
# Cold ❄️
# The current temperature is 10
# Cold ❄️
# The current temperature is 15
# Cold ❄️
# The current temperature is 20
# Good 🟩
# The current temperature is 25
# Good 🟩
# The current temperature is 30
# Hot 🔥
# The current temperature is 35
# Hot 🔥
# The current temperature is 40
# Hot 🔥
# The current temperature is 45
